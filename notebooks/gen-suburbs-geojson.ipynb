# %%
import pandas as pd
import numpy as np
import geopandas as gpd


base_url = 'https://www.abs.gov.au/statistics/standards/australian-statistical-geography-standard-asgs-edition-3/jul2021-jun2026/access-and-downloads/allocation-files'


df_MB = pd.read_excel(f'{base_url}/MB_2021_AUST.xlsx')
# 3m 30s


df_LGA = pd.read_excel(f'{base_url}/LGA_2023_AUST.xlsx')
# 2m


df_SAL = pd.read_excel(f'{base_url}/SAL_2021_AUST.xlsx')
# 3m 30s


df_POA = pd.read_excel(f'{base_url}/POA_2021_AUST.xlsx')
# 2m


df = pd.merge(df_MB, df_LGA, on='MB_CODE_2021', how='left', suffixes=('', '_LGA'))
df = pd.merge(df, df_SAL, on='MB_CODE_2021', how='left', suffixes=('', '_SAL'))
df = pd.merge(df, df_POA, on='MB_CODE_2021', how='left', suffixes=('', '_POA'))
# 10s

# Drop duplicate columns
df.drop(columns=['STATE_CODE_2021_LGA', 'STATE_NAME_2021_LGA', 'AUS_CODE_2021_LGA', 'AUS_NAME_2021_LGA', 'AREA_ALBERS_SQKM_LGA', 'ASGS_LOCI_URI_2021_LGA', 'STATE_CODE_2021_SAL', 'STATE_NAME_2021_SAL', 'AUS_CODE_2021_SAL', 'AUS_NAME_2021_SAL', 'AREA_ALBERS_SQKM_SAL', 'ASGS_LOCI_URI_2021_SAL', 'AUS_CODE_2021_POA', 'AUS_NAME_2021_POA', 'AREA_ALBERS_SQKM_POA', 'ASGS_LOCI_URI_2021_POA'], inplace=True)


gdf : gpd.GeoDataFrame = gpd.read_file('local/MB_2021_AUST_SHP_GDA2020/MB_2021_AUST_GDA2020.shp')
# 8m

gdf : gpd.GeoDataFrame = gdf[['MB_CODE21', 'geometry']].rename(columns={'MB_CODE21': 'MB_CODE_2021'}).merge(df, on='MB_CODE_2021', how='left')
# 10s

gdf_suburbs = gdf[['SAL_CODE_2021', 'POA_CODE_2021', 'geometry']].dissolve(by=['SAL_CODE_2021', 'POA_CODE_2021']).reset_index()
# 3m 30s


df_suburbs = df[['SAL_CODE_2021', 'POA_CODE_2021', 'STATE_CODE_2021', 'AUS_CODE_2021']].drop_duplicates().reset_index(drop=True)

# gdf_suburbs_area = df.groupby(['SAL_CODE_2021', 'POA_CODE_2021', 'STATE_CODE_2021', 'AUS_CODE_2021'])['AREA_ALBERS_SQKM'].sum().reset_index()
# Out:
# C:\Users\An\AppData\Roaming\Python\Python312\site-packages\geopandas\geodataframe.py:1815: FutureWarning: `unary_union` returned None due to all-None GeoSeries. In future, `unary_union` will return 'GEOMETRYCOLLECTION EMPTY' instead.
#   merged_geom = block.unary_union

# %%
df_suburbs_info = df[[
    'SAL_CODE_2021',
    'POA_CODE_2021',
    'STATE_CODE_2021',
    'AUS_CODE_2021',
    'SAL_NAME_2021',
    'POA_NAME_2021',
    'STATE_NAME_2021',
    'AUS_NAME_2021',
]].drop_duplicates().reset_index(drop=True)

# %%
df_suburbs_area = df.groupby(['SAL_CODE_2021','POA_CODE_2021'])['AREA_ALBERS_SQKM'].sum().reset_index()

# %%
df_suburbs_area
# Out:
#       SAL_CODE_2021 POA_CODE_2021  AREA_ALBERS_SQKM
# 0             10001          2850           82.7639
# 1             10002          2176            4.9788
# 2             10003          2046            1.0180
# 3             10004          2795            2.9775
# 4             10005          2795          127.1701
# ...             ...           ...               ...
# 15535         90004          2899           38.6510
# 15536         90005          6799            5.9276
# 15537         99494          9494            0.0000
# 15538         99797          9797            0.0000
# 15539         ZZZZZ          ZZZZ            0.0000
#
# [15540 rows x 3 columns]

# %%
gdf_suburbs : gpd.GeoDataFrame = gdf_suburbs.merge(df_suburbs_area, on=['SAL_CODE_2021', 'POA_CODE_2021'], how='left').merge(df_suburbs_info, on=['SAL_CODE_2021', 'POA_CODE_2021'], how='left')

# %%
gdf_suburbs.rename(columns={
    'SAL_CODE_2021' : 'suburb_id',
    'POA_CODE_2021' : 'postcode_id',
    'STATE_CODE_2021' : 'state_id',
    'AUS_CODE_2021' : 'country_id',
    'SAL_NAME_2021' : 'suburb',
    'POA_NAME_2021' : 'postcode',
    'STATE_NAME_2021' : 'state_name',
    'AUS_NAME_2021' : 'country_name',
    'AREA_ALBERS_SQKM' : 'area_sqkm',
}, inplace=True)

gdf_suburbs['state'] = gdf_suburbs['state_id'].map({
    '1' : 'NSW',
    '2' : 'VIC',
    '3' : 'QLD',
    '4' : 'SA',
    '5' : 'WA',
    '6' : 'TAS',
    '7' : 'NT',
    '8' : 'ACT',
    '9' : 'Other Territories',
    'Z' : 'Outside Australia',
})

# %%
gdf_suburbs
# Out:
#       suburb_id postcode_id  \
# 0         10001        2850
# 1         10002        2176
# 2         10003        2046
# 3         10004        2795
# 4         10005        2795
# ...         ...         ...
# 15535     90004        2899
# 15536     90005        6799
# 15537     99494        9494
# 15538     99797        9797
# 15539     ZZZZZ        ZZZZ
#
#                                                 geometry  area_sqkm state_id  \
# 0      POLYGON ((149.74733 -32.91034, 149.74741 -32.9...    82.7639        1
# 1      POLYGON ((150.86479 -33.88339, 150.86463 -33.8...     4.9788        1
# 2      POLYGON ((151.12703 -33.85554, 151.12693 -33.8...     1.0180        1
# 3      POLYGON ((149.54550 -33.39044, 149.54361 -33.3...     2.9775        1
# 4      POLYGON ((149.25562 -33.96535, 149.25563 -33.9...   127.1701        1
# ...                                                  ...        ...      ...
# 15535  MULTIPOLYGON (((167.94108 -29.06217, 167.94131...    38.6510        9
# 15536  MULTIPOLYGON (((96.83046 -12.17626, 96.83048 -...     5.9276        9
# 15537                                               None     0.0000        9
# 15538  MULTIPOLYGON (((167.97281 -29.01566, 167.97384...     0.0000        9
# 15539                                               None     0.0000        Z
#
#       country_id                                suburb  \
# 0            AUS                           Aarons Pass
# 1            AUS                            Abbotsbury
# 2            AUS                      Abbotsford (NSW)
# 3            AUS                           Abercrombie
# 4            AUS                     Abercrombie River
# ...          ...                                   ...
# 15535        AUS                        Norfolk Island
# 15536        AUS                           West Island
# 15537        AUS                 No usual address (OT)
# 15538        AUS  Migratory - Offshore - Shipping (OT)
# 15539        ZZZ                     Outside Australia
#
#                                       postcode         state_name  \
# 0                                         2850    New South Wales
# 1                                         2176    New South Wales
# 2                                         2046    New South Wales
# 3                                         2795    New South Wales
# 4                                         2795    New South Wales
# ...                                        ...                ...
# 15535                                     2899  Other Territories
# 15536                                     6799  Other Territories
# 15537                 No usual address (Aust.)  Other Territories
# 15538  Migratory - Offshore - Shipping (Aust.)  Other Territories
# 15539                        Outside Australia  Outside Australia
#
#             country_name              state
# 0              Australia                NSW
# 1              Australia                NSW
# 2              Australia                NSW
# 3              Australia                NSW
# 4              Australia                NSW
# ...                  ...                ...
# 15535          Australia  Other Territories
# 15536          Australia  Other Territories
# 15537          Australia  Other Territories
# 15538          Australia  Other Territories
# 15539  Outside Australia  Outside Australia
#
# [15540 rows x 11 columns]

# %%
# Split the suburbs into separate states, and for each state, split into 5 geojson files
for state_id in states.keys():
    gdfs = gdf_suburbs[gdf_suburbs['state_id'] == state_id]
    # Sort by postcode
    gdfs.sort_values('postcode', inplace=True)
    gdfs.reset_index(drop=True, inplace=True)
    # Split into 5 geojson files
    n = len(gdfs)
    n_per_file = n // 5
    for i in range(5):
        gdfs[i*n_per_file:(i+1)*n_per_file].to_file(f'local/suburbs-{states[state_id]}-{i}.geojson', driver='GeoJSON')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File c:\Users\An\Documents\GitHub\AusGeo\gen-suburbs-geojson.py:3
#       1 # %%
#       2 # Split the suburbs into separate states, and for each state, split into 5 geojson files
# ----> 3 for state_id in states.keys():
#       4     gdfs = gdf_suburbs[gdf_suburbs['state_id'] == state_id]
#       5     # Sort by postcode
#
# NameError: name 'states' is not defined

# %%
states = {
    '1' : 'NSW',
    '2' : 'VIC',
    '3' : 'QLD',
    '4' : 'SA',
    '5' : 'WA',
    '6' : 'TAS',
    '7' : 'NT',
    '8' : 'ACT',
    '9' : 'Other Territories',
    'Z' : 'Outside Australia',
}
gdf_suburbs['state'] = gdf_suburbs['state_id'].map(states)

# %%
# Split the suburbs into separate states, and for each state, split into 5 geojson files
for state_id in states.keys():
    gdfs = gdf_suburbs[gdf_suburbs['state_id'] == state_id]
    # Sort by postcode
    gdfs.sort_values('postcode', inplace=True)
    gdfs.reset_index(drop=True, inplace=True)
    # Split into 5 geojson files
    n = len(gdfs)
    n_per_file = n // 5
    for i in range(5):
        gdfs[i*n_per_file:(i+1)*n_per_file].to_file(f'local/suburbs-{states[state_id]}-{i}.geojson', driver='GeoJSON')
# Out:
# <ipython-input-10-9ddc70620e2a>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdfs.sort_values('postcode', inplace=True)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File c:\Users\An\Documents\GitHub\AusGeo\gen-suburbs-geojson.py:12
#      10 n_per_file = n // 5
#      11 for i in range(5):
# ---> 12     gdfs[i*n_per_file:(i+1)*n_per_file].to_file(f'local/suburbs-{states[state_id]}-{i}.geojson', driver='GeoJSON')
#
# File ~\AppData\Roaming\Python\Python312\site-packages\geopandas\geodataframe.py:1264, in GeoDataFrame.to_file(self, filename, driver, schema, index, **kwargs)
#    1173 """Write the ``GeoDataFrame`` to a file.
#    1174
#    1175 By default, an ESRI shapefile is written, but any OGR data source
#    (...)
#    1260
#    1261 """
#    1262 from geopandas.io.file import _to_file
# -> 1264 _to_file(self, filename, driver, schema, index, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\geopandas\io\file.py:608, in _to_file(df, filename, driver, schema, index, mode, crs, engine, **kwargs)
#     605     raise ValueError(f"'mode' should be one of 'w' or 'a', got '{mode}' instead")
#     607 if engine == "fiona":
# --> 608     _to_file_fiona(df, filename, driver, schema, crs, mode, **kwargs)
#     609 elif engine == "pyogrio":
#     610     _to_file_pyogrio(df, filename, driver, schema, crs, mode, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\geopandas\io\file.py:637, in _to_file_fiona(df, filename, driver, schema, crs, mode, **kwargs)
#     633     crs_wkt = crs.to_wkt("WKT1_GDAL")
#     634 with fiona.open(
#     635     filename, mode=mode, driver=driver, crs_wkt=crs_wkt, schema=schema, **kwargs
#     636 ) as colxn:
# --> 637     colxn.writerecords(df.iterfeatures())
#
# File ~\AppData\Roaming\Python\Python312\site-packages\fiona\collection.py:558, in Collection.writerecords(self, records)
#     556 if self.mode not in ("a", "w"):
#     557     raise OSError("collection not open for writing")
# --> 558 self.session.writerecs(records, self)
#     559 self._len = self.session.get_length()
#     560 self._bounds = None
#
# File fiona\\ogrext.pyx:1392, in fiona.ogrext.WritingSession.writerecs()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\geopandas\geodataframe.py:951, in GeoDataFrame.iterfeatures(self, na, show_bbox, drop_id)
#     949 feature["type"] = "Feature"
#     950 feature["properties"] = properties_items
# --> 951 feature["geometry"] = mapping(geom) if geom else None
#     953 if show_bbox:
#     954     feature["bbox"] = geom.bounds if geom else None
#
# File ~\AppData\Roaming\Python\Python312\site-packages\shapely\geometry\geo.py:135, in mapping(ob)
#     115 def mapping(ob):
#     116     """
#     117     Returns a GeoJSON-like mapping from a Geometry or any
#     118     object which implements __geo_interface__
#    (...)
#     133     {'type': 'Point', 'coordinates': (0.0, 0.0)}
#     134     """
# --> 135     return ob.__geo_interface__
#
# File ~\AppData\Roaming\Python\Python312\site-packages\shapely\geometry\polygon.py:291, in Polygon.__geo_interface__(self)
#     289 @property
#     290 def __geo_interface__(self):
# --> 291     if self.exterior == LinearRing():
#     292         coords = []
#     293     else:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\shapely\geometry\base.py:206, in BaseGeometry.__eq__(self, other)
#     202     return NotImplemented
#     203 # equal_nan=False is the default, but not yet available for older numpy
#     204 # TODO updated once we require numpy >= 1.19
#     205 return type(other) == type(self) and np.array_equal(
# --> 206     self.coords, other.coords  # , equal_nan=False
#     207 )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\shapely\geometry\base.py:223, in BaseGeometry.coords(self)
#     220 @property
#     221 def coords(self):
#     222     """Access to geometry's coordinates (CoordinateSequence)"""
# --> 223     coords_array = shapely.get_coordinates(self, include_z=self.has_z)
#     224     return CoordinateSequence(coords_array)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\shapely\geometry\base.py:624, in BaseGeometry.has_z(self)
#     620 @property
#     621 def has_z(self):
#     622     """True if the geometry's coordinate sequence(s) have z values (are
#     623     3-dimensional)"""
# --> 624     return bool(shapely.has_z(self))
#
# File ~\AppData\Roaming\Python\Python312\site-packages\shapely\decorators.py:77, in multithreading_enabled.<locals>.wrapped(*args, **kwargs)
#      75     for arr in array_args:
#      76         arr.flags.writeable = False
# ---> 77     return func(*args, **kwargs)
#      78 finally:
#      79     for arr, old_flag in zip(array_args, old_flags):
#
# File ~\AppData\Roaming\Python\Python312\site-packages\shapely\predicates.py:68, in has_z(geometry, **kwargs)
#      41 @multithreading_enabled
#      42 def has_z(geometry, **kwargs):
#      43     """Returns True if a geometry has a Z coordinate.
#      44
#      45     Note that this function returns False if the (first) Z coordinate equals NaN or
#    (...)
#      66     False
#      67     """
# ---> 68     return lib.has_z(geometry, **kwargs)
#
# KeyboardInterrupt:

# %%
# Split the suburbs into separate states, and for each state, split into 5 geojson files
for state_id in states.keys():
    gdfs = gdf_suburbs[gdf_suburbs['state_id'] == state_id].sort_values('postcode').reset_index(drop=True)
    # Split into 5 geojson files
    n = len(gdfs)
    n_per_file = n // 5
    for i in range(5):
        gdfs[i*n_per_file:(i+1)*n_per_file].to_file(f'local/suburbs-{states[state_id]}-{i}.geojson', driver='GeoJSON')
        print(f'local/suburbs-{states[state_id]}-{i}.geojson')
# Out:
# local/suburbs-NSW-0.geojson
# local/suburbs-NSW-1.geojson
# local/suburbs-NSW-2.geojson
# local/suburbs-NSW-3.geojson
# local/suburbs-NSW-4.geojson
# local/suburbs-VIC-0.geojson
# local/suburbs-VIC-1.geojson
# local/suburbs-VIC-2.geojson
# local/suburbs-VIC-3.geojson
# local/suburbs-VIC-4.geojson
# local/suburbs-QLD-0.geojson
# local/suburbs-QLD-1.geojson
# local/suburbs-QLD-2.geojson
# local/suburbs-QLD-3.geojson
# local/suburbs-QLD-4.geojson
# local/suburbs-SA-0.geojson
# local/suburbs-SA-1.geojson
# local/suburbs-SA-2.geojson
# local/suburbs-SA-3.geojson
# local/suburbs-SA-4.geojson
# local/suburbs-WA-0.geojson
# local/suburbs-WA-1.geojson
# local/suburbs-WA-2.geojson
# local/suburbs-WA-3.geojson
# local/suburbs-WA-4.geojson
# local/suburbs-TAS-0.geojson
# local/suburbs-TAS-1.geojson
# local/suburbs-TAS-2.geojson
# local/suburbs-TAS-3.geojson
# local/suburbs-TAS-4.geojson
# local/suburbs-NT-0.geojson
# local/suburbs-NT-1.geojson
# local/suburbs-NT-2.geojson
# local/suburbs-NT-3.geojson
# local/suburbs-NT-4.geojson
# local/suburbs-ACT-0.geojson
# local/suburbs-ACT-1.geojson
# local/suburbs-ACT-2.geojson
# local/suburbs-ACT-3.geojson
# local/suburbs-ACT-4.geojson
# local/suburbs-Other Territories-0.geojson
# local/suburbs-Other Territories-1.geojson
# local/suburbs-Other Territories-2.geojson
# local/suburbs-Other Territories-3.geojson
# local/suburbs-Other Territories-4.geojson
# local/suburbs-Outside Australia-0.geojson
# local/suburbs-Outside Australia-1.geojson
# local/suburbs-Outside Australia-2.geojson
# local/suburbs-Outside Australia-3.geojson
# local/suburbs-Outside Australia-4.geojson
# C:\Users\An\AppData\Roaming\Python\Python312\site-packages\geopandas\io\file.py:608: UserWarning: You are attempting to write an empty DataFrame to file. For some drivers, this operation may fail.
#   _to_file_fiona(df, filename, driver, schema, crs, mode, **kwargs)
# C:\Users\An\AppData\Roaming\Python\Python312\site-packages\geopandas\io\file.py:608: UserWarning: You are attempting to write an empty DataFrame to file. For some drivers, this operation may fail.
#   _to_file_fiona(df, filename, driver, schema, crs, mode, **kwargs)
# C:\Users\An\AppData\Roaming\Python\Python312\site-packages\geopandas\io\file.py:608: UserWarning: You are attempting to write an empty DataFrame to file. For some drivers, this operation may fail.
#   _to_file_fiona(df, filename, driver, schema, crs, mode, **kwargs)
# C:\Users\An\AppData\Roaming\Python\Python312\site-packages\geopandas\io\file.py:608: UserWarning: You are attempting to write an empty DataFrame to file. For some drivers, this operation may fail.
#   _to_file_fiona(df, filename, driver, schema, crs, mode, **kwargs)
# C:\Users\An\AppData\Roaming\Python\Python312\site-packages\geopandas\io\file.py:608: UserWarning: You are attempting to write an empty DataFrame to file. For some drivers, this operation may fail.
#   _to_file_fiona(df, filename, driver, schema, crs, mode, **kwargs)
